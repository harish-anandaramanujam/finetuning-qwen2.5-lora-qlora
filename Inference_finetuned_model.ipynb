# %% [markdown]
# ## Predict Product Prices
#
# ### And now, to evaluate our fine-tuned open source model

# %%
# pip installs

# !pip install -q --upgrade torch==2.5.1+cu124 torchvision==0.20.1+cu124 torchaudio==2.5.1+cu124 --index-url https://download.pytorch.org/whl/cu124
# !pip install -q --upgrade requests==2.32.3 bitsandbytes==0.46.0 transformers==4.48.3 accelerate==1.3.0 datasets==3.2.0 peft==0.14.0 trl==0.14.0 matplotlib wandb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.2/908.2 MB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 36.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 19.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 40.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 91.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 107.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.6/209.6 MB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 103.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 111.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.6/336.6 kB 31.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 30.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.8/374.8 kB 19.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.9/313.9 kB 24.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 94.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 83.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 14.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 62.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.9.0 which is incompatible.
# google-adk 1.17.0 requires requests<3.0.0,>=2.32.4, but you have requests 2.32.3 which is incompatible.

# %%
# imports

import os
import re
import math
from tqdm import tqdm
from google.colab import userdata
from huggingface_hub import login
import torch
import torch.nn.functional as F
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, set_seed
from datasets import load_dataset, Dataset, DatasetDict
from datetime import datetime
from peft import PeftModel
import matplotlib.pyplot as plt

# %%
# Constants

BASE_MODEL = "Qwen/Qwen2.5-7B"
PROJECT_NAME = "pricer"
HF_USER = "harish-anandaramanujam"

# The run itself

RUN_NAME = "2025-10-29_05.43.51"
PROJECT_RUN_NAME = f"{PROJECT_NAME}-{RUN_NAME}"
REVISION = None
FINETUNED_MODEL = f"{HF_USER}/{PROJECT_RUN_NAME}"

# Data
DATASET_NAME = f"{HF_USER}/amzn-appliances-price-lite-data"


# Hyperparameters for QLoRA
QUANT_4_BIT = True

# %matplotlib inline

# Used for writing to output in color

GREEN = "\033[92m"
YELLOW = "\033[93m"
RED = "\033[91m"
RESET = "\033[0m"
COLOR_MAP = {"red":RED, "orange": YELLOW, "green": GREEN}

# %% [markdown]
# ### Log in to HuggingFace

# %%
# Log in to HuggingFace

hf_token = userdata.get('HF_TOKEN')
login(hf_token, add_to_git_credential=True)

# %%
dataset = load_dataset(DATASET_NAME)
train = dataset['train']
test = dataset['test']
# Out:
# README.md:   0%|          | 0.00/412 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/9.50M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/759k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
test[0]
# Out:
# {'text': 'How much does this cost to the nearest dollar?\n\nCONTINENTAL REFRIGERATOR 2-705 Gasket, SNAP in\nSPECIFICATIONS LENGTH 22 3/8, 568 mm WIDTH 25 3/8, 644 mm WEIGHT 1.225 lb GASKET TYPE 4 SIDED, MAGNETIC, DART PART REFERENCE INFO CONTINENTAL REFRIGERATOR 2-705 MODEL REFERENCE INFO CONTINENTAL REFRIGERATOR WORK TOP REFRIGERATOR MODELS SW48 CONTINENTAL REFRIGERATOR REFRIGERATOR DOOR GASKET 2-705 High Quality Gasket Brand Name Continental Refrigerator, Model Info Weight 1.2\n\nPrice is $',
#  'price': 36.22}

# %% [markdown]
# ## Now load the Tokenizer and Model

# %%
# pick the right quantization (thank you Robert M. for spotting the bug with the 8 bit version!)

if QUANT_4_BIT:
  quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_quant_type="nf4"
  )
else:
  quant_config = BitsAndBytesConfig(
    load_in_8bit=True,
    bnb_8bit_compute_dtype=torch.bfloat16
  )

# %%
# Load the Tokenizer and the Model

tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=quant_config,
    device_map="auto",
)
base_model.generation_config.pad_token_id = tokenizer.pad_token_id

# Load the fine-tuned model with PEFT
if REVISION:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL, revision=REVISION)
else:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL)


print(f"Memory footprint: {fine_tuned_model.get_memory_footprint() / 1e6:.1f} MB")
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/686 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/3.95G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/3.56G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/138 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/739 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/80.8M [00:00<?, ?B/s]
# Memory footprint: 5524.0 MB

# %%
fine_tuned_model
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): Qwen2ForCausalLM(
#       (model): Qwen2Model(
#         (embed_tokens): Embedding(152064, 3584)
#         (layers): ModuleList(
#           (0-27): 28 x Qwen2DecoderLayer(
#             (self_attn): Qwen2Attention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=3584, out_features=3584, bias=True)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=3584, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=3584, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=3584, out_features=512, bias=True)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=3584, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=512, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=3584, out_features=512, bias=True)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=3584, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=512, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=3584, out_features=3584, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=3584, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=3584, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#             )
#             (mlp): Qwen2MLP(
#               (gate_proj): Linear4bit(in_features=3584, out_features=18944, bias=False)
#               (up_proj): Linear4bit(in_features=3584, out_features=18944, bias=False)
#               (down_proj): Linear4bit(in_features=18944, out_features=3584, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): Qwen2RMSNorm((3584,), eps=1e-06)
#             (post_attention_layernorm): Qwen2RMSNorm((3584,), eps=1e-06)
#           )
#         )
#         (norm): Qwen2RMSNorm((3584,), eps=1e-06)
#         (rotary_emb): Qwen2RotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=3584, out_features=152064, bias=False)
#     )
#   )
# )

# %% [markdown]
# # THE MOMENT OF TRUTH!

# %%
def extract_price(s):
    if "Price is $" in s:
      contents = s.split("Price is $")[1]
      contents = contents.replace(',','')
      match = re.search(r"[-+]?\d*\.\d+|\d+", contents)
      return float(match.group()) if match else 0
    return 0

# %%
extract_price("Price is $a fabulous 899.99 or so")
# Out:
# 899.99

# %%
# Original prediction function takes the most likely next token

def model_predict(prompt):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to("cuda")
    attention_mask = torch.ones(inputs.shape, device="cuda")
    outputs = fine_tuned_model.generate(inputs, attention_mask=attention_mask, max_new_tokens=3, num_return_sequences=1)
    response = tokenizer.decode(outputs[0])
    return extract_price(response)

# %%
# An improved prediction function takes a weighted average of the top 3 choices
# This code would be more complex if we couldn't take advantage of the fact
# That Llama generates 1 token for any 3 digit number

top_K = 3

def improved_model_predict(prompt, device="cuda"):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to(device)
    attention_mask = torch.ones(inputs.shape, device=device)

    with torch.no_grad():
        outputs = fine_tuned_model(inputs, attention_mask=attention_mask)
        next_token_logits = outputs.logits[:, -1, :].to('cpu')

    next_token_probs = F.softmax(next_token_logits, dim=-1)
    top_prob, top_token_id = next_token_probs.topk(top_K)
    prices, weights = [], []
    for i in range(top_K):
      predicted_token = tokenizer.decode(top_token_id[0][i])
      probability = top_prob[0][i]
      try:
        result = float(predicted_token)
      except ValueError as e:
        result = 0.0
      if result > 0:
        prices.append(result)
        weights.append(probability)
    if not prices:
      return 0.0, 0.0
    total = sum(weights)
    weighted_prices = [price * weight / total for price, weight in zip(prices, weights)]
    return sum(weighted_prices).item()

# %%
class Tester:

    def __init__(self, predictor, data, title=None, size=250):
        self.predictor = predictor
        self.data = data
        self.title = title or predictor.__name__.replace("_", " ").title()
        self.size = size
        self.guesses = []
        self.truths = []
        self.errors = []
        self.sles = []
        self.colors = []

    def color_for(self, error, truth):
        if error<40 or error/truth < 0.2:
            return "green"
        elif error<80 or error/truth < 0.4:
            return "orange"
        else:
            return "red"

    def run_datapoint(self, i):
        datapoint = self.data[i]
        guess = self.predictor(datapoint["text"])
        truth = datapoint["price"]
        error = abs(guess - truth)
        log_error = math.log(truth+1) - math.log(guess+1)
        sle = log_error ** 2
        color = self.color_for(error, truth)
        title = datapoint["text"].split("\n\n")[1][:20] + "..."
        self.guesses.append(guess)
        self.truths.append(truth)
        self.errors.append(error)
        self.sles.append(sle)
        self.colors.append(color)
        print(f"{COLOR_MAP[color]}{i+1}: Guess: ${guess:,.2f} Truth: ${truth:,.2f} Error: ${error:,.2f} SLE: {sle:,.2f} Item: {title}{RESET}")

    def chart(self, title):
        max_error = max(self.errors)
        plt.figure(figsize=(12, 8))
        max_val = max(max(self.truths), max(self.guesses))
        plt.plot([0, max_val], [0, max_val], color='deepskyblue', lw=2, alpha=0.6)
        plt.scatter(self.truths, self.guesses, s=3, c=self.colors)
        plt.xlabel('Ground Truth')
        plt.ylabel('Model Estimate')
        plt.xlim(0, max_val)
        plt.ylim(0, max_val)
        plt.title(title)
        plt.show()

    def report(self):
        average_error = sum(self.errors) / self.size
        rmsle = math.sqrt(sum(self.sles) / self.size)
        hits = sum(1 for color in self.colors if color=="green")
        title = f"{self.title} Error=${average_error:,.2f} RMSLE={rmsle:,.2f} Hits={hits/self.size*100:.1f}%"
        self.chart(title)

    def run(self):
        self.error = 0
        for i in range(self.size):
            self.run_datapoint(i)
        self.report()

    @classmethod
    def test(cls, function, data):
        cls(function, data).run()

# %%
Tester.test(improved_model_predict, test)
# Out:
# 1: Guess: $3.09 Truth: $36.22 Error: $33.13 SLE: 4.87 Item: CONTINENTAL REFRIGER...
# 2: Guess: $3.93 Truth: $880.00 Error: $876.07 SLE: 26.90 Item: 12,000 BTU CoVac Duc...
# 3: Guess: $3.02 Truth: $95.67 Error: $92.65 SLE: 10.11 Item: Whirlpool Oven
# Produ...
# 4: Guess: $4.01 Truth: $21.98 Error: $17.97 SLE: 2.32 Item: Frigidaire Basket
# Th...
# 5: Guess: $2.07 Truth: $95.14 Error: $93.07 SLE: 11.85 Item: GE Genuine OEM Compr...
# 6: Guess: $2.90 Truth: $8.99 Error: $6.09 SLE: 0.89 Item: 6 Pack Reusable K Cu...
# 7: Guess: $1.58 Truth: $8.66 Error: $7.08 SLE: 1.74 Item: Silicone Kitchen Sto...
# 8: Guess: $3.01 Truth: $42.52 Error: $39.51 SLE: 5.69 Item: Whirlpool Refrigerat...
# 9: Guess: $5.16 Truth: $9.99 Error: $4.83 SLE: 0.33 Item: Oven Temperature Sen...
# 10: Guess: $1.68 Truth: $42.99 Error: $41.31 SLE: 7.82 Item: Upgraded Full Real M...
# 11: Guess: $2.10 Truth: $21.99 Error: $19.89 SLE: 4.02 Item: BUNN Basket Filter (...
# 12: Guess: $2.02 Truth: $53.98 Error: $51.96 SLE: 8.43 Item: Vuenyrun Automatic E...
# 13: Guess: $1.64 Truth: $20.99 Error: $19.35 SLE: 4.49 Item: Replacement Aluminum...
# 14: Guess: $1.32 Truth: $14.99 Error: $13.67 SLE: 3.72 Item: FQQWEE Egg Holder fo...
# 15: Guess: $1.42 Truth: $259.99 Error: $258.57 SLE: 21.91 Item: MAT EXPERT 3.4 Cu.Ft...
# 16: Guess: $2.01 Truth: $250.33 Error: $248.32 SLE: 19.59 Item: GE Icemaker Assembly...
# 17: Guess: $2.04 Truth: $34.59 Error: $32.55 SLE: 6.06 Item: Refrigerator Defrost...
# 18: Guess: $1.99 Truth: $275.99 Error: $274.00 SLE: 20.51 Item: 30 Inch Gas Cooktop ...
# 19: Guess: $1.89 Truth: $19.96 Error: $18.07 SLE: 3.93 Item: Washer Drain Pump Mo...
# 20: Guess: $3.38 Truth: $6.99 Error: $3.61 SLE: 0.36 Item: Dryer Timer Control ...
# 21: Guess: $1.68 Truth: $6.59 Error: $4.91 SLE: 1.08 Item: Coffee Paper Filter ...
# 22: Guess: $2.17 Truth: $343.99 Error: $341.82 SLE: 21.98 Item: Range Hood 30 inch w...
# 23: Guess: $1.69 Truth: $21.99 Error: $20.30 SLE: 4.60 Item: GRONGU Cold Brew Cof...
# 24: Guess: $3.08 Truth: $9.99 Error: $6.91 SLE: 0.98 Item: Dryer Lint Filter Re...
# 25: Guess: $1.95 Truth: $77.05 Error: $75.10 SLE: 10.73 Item: Berkel Carriage Knob...
# 26: Guess: $1.59 Truth: $19.95 Error: $18.36 SLE: 4.37 Item: Perfect Pod Eco-Fill...
# 27: Guess: $1.48 Truth: $21.99 Error: $20.51 SLE: 4.96 Item: Range Kleen Style A ...
# 28: Guess: $3.91 Truth: $85.02 Error: $81.11 SLE: 8.19 Item: GENUINE Whirlpool Hi...
# 29: Guess: $1.48 Truth: $20.85 Error: $19.37 SLE: 4.73 Item: Cold Water lnlet Val...
# 30: Guess: $1.31 Truth: $20.86 Error: $19.55 SLE: 5.05 Item: (4 PACK) - Deflecto ...
# 31: Guess: $2.27 Truth: $167.33 Error: $165.06 SLE: 15.53 Item: Igloo Automatic Self...
# 32: Guess: $1.38 Truth: $9.88 Error: $8.50 SLE: 2.31 Item: COT Made for Sunny D...
# 33: Guess: $3.11 Truth: $52.87 Error: $49.76 SLE: 6.63 Item: Whirlpool Temperatur...
# 34: Guess: $1.59 Truth: $9.99 Error: $8.40 SLE: 2.09 Item: 2-Pack Single Serve ...
# 35: Guess: $1.86 Truth: $11.34 Error: $9.48 SLE: 2.14 Item: Compatible With Whir...
# 36: Guess: $2.41 Truth: $5.99 Error: $3.58 SLE: 0.52 Item: Reusable K Cups, 2 P...
# 37: Guess: $3.04 Truth: $32.29 Error: $29.25 SLE: 4.45 Item: Supco WV9346 Washer ...
# 38: Guess: $1.82 Truth: $30.79 Error: $28.97 SLE: 5.87 Item: Sensor OEM Mania New...
# 39: Guess: $1.61 Truth: $14.99 Error: $13.38 SLE: 3.28 Item: Supplying Demand Ref...
# 40: Guess: $1.54 Truth: $14.97 Error: $13.43 SLE: 3.39 Item: Fit for Samsung Drye...
# 41: Guess: $2.68 Truth: $36.99 Error: $34.31 SLE: 5.45 Item: 5 Pack Range Burner ...
# 42: Guess: $2.91 Truth: $99.95 Error: $97.04 SLE: 10.57 Item: Case Club Pre-Cut Wa...
# 43: Guess: $1.42 Truth: $18.65 Error: $17.23 SLE: 4.39 Item: Carbon Range Filter ...
# 44: Guess: $1.52 Truth: $12.99 Error: $11.47 SLE: 2.93 Item: Humidity and Tempera...
# 45: Guess: $2.94 Truth: $46.12 Error: $43.18 SLE: 6.16 Item: General Electric Ref...
# 46: Guess: $2.70 Truth: $19.99 Error: $17.29 SLE: 3.01 Item: IOYIJOI Humidifier F...
# 47: Guess: $4.50 Truth: $9.97 Error: $5.47 SLE: 0.48 Item: Refrigerator Defrost...
# 48: Guess: $2.12 Truth: $18.95 Error: $16.83 SLE: 3.45 Item: Lifetime Dryer Heati...
# 49: Guess: $1.52 Truth: $179.99 Error: $178.47 SLE: 18.26 Item: Weceleh Induction Co...
# 50: Guess: $3.75 Truth: $6.49 Error: $2.74 SLE: 0.21 Item: 25 Universal Gray Gr...
# 51: Guess: $1.95 Truth: $25.98 Error: $24.03 SLE: 4.90 Item: CAPMESSO Coffee Caps...
# 52: Guess: $2.92 Truth: $48.49 Error: $45.57 SLE: 6.43 Item: OCTOPUS Compatible w...
# 53: Guess: $1.29 Truth: $13.99 Error: $12.70 SLE: 3.53 Item: EXCELPURE Replacemen...
# 54: Guess: $1.57 Truth: $15.63 Error: $14.06 SLE: 3.49 Item: Sealed Unit Parts SU...
# 55: Guess: $3.91 Truth: $320.41 Error: $316.50 SLE: 17.48 Item: Summit Wide 115V Rad...
# 56: Guess: $2.33 Truth: $103.77 Error: $101.44 SLE: 11.89 Item: ForeverPRO Timer for...
# 57: Guess: $2.93 Truth: $27.89 Error: $24.96 SLE: 3.98 Item: Dishwasher Door Cove...
# 58: Guess: $2.67 Truth: $85.04 Error: $82.37 SLE: 9.96 Item: Scotsman Magnetic Ga...
# 59: Guess: $1.88 Truth: $10.99 Error: $9.11 SLE: 2.04 Item: Coffee Filter Basket...
# 60: Guess: $3.08 Truth: $9.98 Error: $6.90 SLE: 0.98 Item: YQL #2 Cone Coffee F...
# 61: Guess: $1.26 Truth: $12.39 Error: $11.13 SLE: 3.16 Item: MEISHIDA Egg Holder ...
# 62: Guess: $1.47 Truth: $41.59 Error: $40.12 SLE: 8.11 Item: Washer Door Lock Lat...
# 63: Guess: $2.03 Truth: $33.99 Error: $31.96 SLE: 5.99 Item: FrigiLife Replacemen...
# 64: Guess: $1.62 Truth: $150.18 Error: $148.56 SLE: 16.45 Item: STAR Lower Door
# Prod...
# 65: Guess: $1.40 Truth: $17.99 Error: $16.59 SLE: 4.28 Item: i Cafilas Refillable...
# 66: Guess: $1.80 Truth: $23.99 Error: $22.19 SLE: 4.79 Item: 279838 Dryer Heating...
# 67: Guess: $2.76 Truth: $9.90 Error: $7.14 SLE: 1.13 Item: steel filter 10pcs a...
# 68: Guess: $1.43 Truth: $24.95 Error: $23.52 SLE: 5.61 Item: 6' STAINLESS STEEL B...
# 69: Guess: $2.76 Truth: $22.83 Error: $20.07 SLE: 3.41 Item: Dundas Jafine EXWTZW...
# 70: Guess: $1.45 Truth: $12.95 Error: $11.50 SLE: 3.02 Item: GE Part Number FUSE ...
# 71: Guess: $1.59 Truth: $7.91 Error: $6.32 SLE: 1.53 Item: HQRP Filter compatib...
# 72: Guess: $1.53 Truth: $9.22 Error: $7.69 SLE: 1.95 Item: Small Size Pour Over...
# 73: Guess: $1.52 Truth: $36.99 Error: $35.47 SLE: 7.36 Item: HASMX Replacement Hu...
# 74: Guess: $1.49 Truth: $141.51 Error: $140.02 SLE: 16.37 Item: Kit Diaphragm Lid
# 52...
# 75: Guess: $1.69 Truth: $11.99 Error: $10.30 SLE: 2.48 Item: Reusable Grey 3 Part...
# 76: Guess: $1.43 Truth: $20.24 Error: $18.81 SLE: 4.70 Item: Washer Drive Belt - ...
# 77: Guess: $4.70 Truth: $8.89 Error: $4.19 SLE: 0.30 Item: (2023 Update) 661566...
# 78: Guess: $2.71 Truth: $19.97 Error: $17.26 SLE: 3.00 Item: 4-Pack Air Filter Fa...
# 79: Guess: $3.53 Truth: $6.49 Error: $2.96 SLE: 0.25 Item: Cheerock Collapsible...
# 80: Guess: $2.91 Truth: $8.19 Error: $5.28 SLE: 0.73 Item: minansostey 54mm Fil...
# 81: Guess: $1.71 Truth: $17.91 Error: $16.20 SLE: 3.78 Item: HQRP Bearing and Sea...
# 82: Guess: $3.63 Truth: $8.89 Error: $5.26 SLE: 0.58 Item: 2PCS Diverter Seal G...
# 83: Guess: $1.66 Truth: $399.99 Error: $398.33 SLE: 25.14 Item: FREE VILLAGE Commerc...
# 84: Guess: $1.46 Truth: $26.99 Error: $25.53 SLE: 5.91 Item: Supplying Demand 8 P...
# 85: Guess: $2.61 Truth: $107.50 Error: $104.89 SLE: 11.58 Item: Hubbell 8452C Angled...
# 86: Guess: $1.68 Truth: $15.99 Error: $14.31 SLE: 3.41 Item: 6 Pack Keurig Charco...
# 87: Guess: $1.52 Truth: $65.99 Error: $64.47 SLE: 10.76 Item: UPGRADED Dishwasher ...
# 88: Guess: $4.84 Truth: $109.95 Error: $105.11 SLE: 8.67 Item: Dryer Drive Motor Co...
# 89: Guess: $2.91 Truth: $27.99 Error: $25.08 SLE: 4.02 Item: 4pcs Washer Shock Ab...
# 90: Guess: $2.63 Truth: $34.56 Error: $31.93 SLE: 5.20 Item: Kitchen Basics 101 D...
# 91: Guess: $1.33 Truth: $9.99 Error: $8.66 SLE: 2.41 Item: Silicone Stove Gap C...
# 92: Guess: $1.80 Truth: $11.99 Error: $10.19 SLE: 2.36 Item: HUIMEIJIA Dryer Drum...
# 93: Guess: $4.24 Truth: $7.89 Error: $3.65 SLE: 0.28 Item: Washer Door Striker,...
# 94: Guess: $2.52 Truth: $31.99 Error: $29.47 SLE: 5.01 Item: Dryer Repair Kit for...
# 95: Guess: $3.16 Truth: $9.99 Error: $6.83 SLE: 0.94 Item: Clip Drain Evaporato...
# 96: Guess: $4.21 Truth: $8.99 Error: $4.78 SLE: 0.42 Item: uxcell 15A Circuit P...
# 97: Guess: $1.61 Truth: $280.00 Error: $278.39 SLE: 21.90 Item: Intermetro Blower
# Pr...
# 98: Guess: $2.29 Truth: $22.99 Error: $20.70 SLE: 3.95 Item: Waterspecialist Refr...
# 99: Guess: $2.07 Truth: $26.79 Error: $24.72 SLE: 4.86 Item: Dryer Repair and Dry...
# 100: Guess: $1.30 Truth: $24.99 Error: $23.69 SLE: 5.87 Item: Vianté V60 Cone Coff...
# 101: Guess: $2.89 Truth: $10.99 Error: $8.10 SLE: 1.26 Item: Marbe Reusable Coffe...
# 102: Guess: $2.68 Truth: $30.95 Error: $28.27 SLE: 4.67 Item: Frigidaire Spark Ele...
# 103: Guess: $2.47 Truth: $26.99 Error: $24.52 SLE: 4.36 Item: ICEPURE PRO Premium ...
# 104: Guess: $1.88 Truth: $28.07 Error: $26.19 SLE: 5.34 Item: UPGRADED SKK-7A SKK8...
# 105: Guess: $2.97 Truth: $36.99 Error: $34.02 SLE: 5.10 Item: PUREPLUS LT500P Repl...
# 106: Guess: $1.96 Truth: $23.99 Error: $22.03 SLE: 4.55 Item: 2-Pack Replacement f...
# 107: Guess: $1.77 Truth: $14.00 Error: $12.23 SLE: 2.85 Item: GE Genuine OEM Door ...
# 108: Guess: $2.05 Truth: $15.50 Error: $13.45 SLE: 2.84 Item: Whole Parts Applianc...
# 109: Guess: $1.92 Truth: $18.90 Error: $16.98 SLE: 3.68 Item: Whirlpool Defrost Bi...
# 110: Guess: $2.99 Truth: $148.99 Error: $146.00 SLE: 13.16 Item: Upgraded Refrigerato...
# 111: Guess: $1.81 Truth: $17.00 Error: $15.19 SLE: 3.45 Item: Samsung Temperature ...
# 112: Guess: $3.95 Truth: $499.00 Error: $495.05 SLE: 21.30 Item: CAVALIERE 36 Wall Mo...
# 113: Guess: $2.06 Truth: $79.99 Error: $77.93 SLE: 10.73 Item: Fridge Fixer for Fis...
# 114: Guess: $2.08 Truth: $192.70 Error: $190.62 SLE: 17.14 Item: Duke 216516 Evaporat...
# 115: Guess: $1.69 Truth: $186.99 Error: $185.30 SLE: 18.05 Item: kitneed Portable Dis...
# 116: Guess: $2.12 Truth: $60.48 Error: $58.36 SLE: 8.89 Item: Replacement Water Fi...
# 117: Guess: $2.96 Truth: $8.29 Error: $5.33 SLE: 0.73 Item: GoldTone Brand Reusa...
# 118: Guess: $3.50 Truth: $51.99 Error: $48.49 SLE: 6.09 Item: Kegco EZ-On Commerci...
# 119: Guess: $4.97 Truth: $119.95 Error: $114.98 SLE: 9.05 Item: GENUINE Whirlpool 63...
# 120: Guess: $3.95 Truth: $45.22 Error: $41.27 SLE: 4.99 Item: Whirlpool SxS Refrig...
# 121: Guess: $6.96 Truth: $75.99 Error: $69.03 SLE: 5.15 Item: IM943 Refrigerator I...
# 122: Guess: $1.35 Truth: $11.88 Error: $10.53 SLE: 2.89 Item: Kujunpao Washing Mac...
# 123: Guess: $1.80 Truth: $15.74 Error: $13.94 SLE: 3.20 Item: Egg Container Paper ...
# 124: Guess: $2.47 Truth: $314.90 Error: $312.43 SLE: 20.35 Item: Wells Thermo Hi Limi...
# 125: Guess: $2.27 Truth: $9.99 Error: $7.72 SLE: 1.47 Item: Gohantee Dryer Idler...
# 126: Guess: $2.18 Truth: $64.90 Error: $62.72 SLE: 9.19 Item: Water Inlet Valve fo...
# 127: Guess: $4.05 Truth: $31.69 Error: $27.64 SLE: 3.49 Item: 5-PACK Top Burner Co...
# 128: Guess: $2.65 Truth: $6.98 Error: $4.33 SLE: 0.61 Item: Mini Digital Thermom...
# 129: Guess: $1.89 Truth: $35.99 Error: $34.10 SLE: 6.50 Item: 5 Pack Range Knob Re...
# 130: Guess: $1.65 Truth: $16.88 Error: $15.23 SLE: 3.65 Item: Replacement Part K C...
# 131: Guess: $2.23 Truth: $22.99 Error: $20.76 SLE: 4.02 Item: 2-Pack Replacement f...
# 132: Guess: $2.68 Truth: $28.99 Error: $26.31 SLE: 4.40 Item: 3-Pack Replacement f...
# 133: Guess: $1.36 Truth: $11.95 Error: $10.59 SLE: 2.89 Item: Ultra Durable 285805...
# 134: Guess: $1.55 Truth: $151.95 Error: $150.40 SLE: 16.75 Item: Frigidaire Control B...
# 135: Guess: $1.84 Truth: $28.95 Error: $27.11 SLE: 5.55 Item: HQRP Wick Filter Rep...
# 136: Guess: $2.85 Truth: $386.15 Error: $383.30 SLE: 21.26 Item: Broan-NuTone Wall-Mo...
# 137: Guess: $1.83 Truth: $27.21 Error: $25.38 SLE: 5.28 Item: Deflecto Supurr-Flex...
# 138: Guess: $1.97 Truth: $19.99 Error: $18.02 SLE: 3.83 Item: Washer Latch Assembl...
# 139: Guess: $2.22 Truth: $110.95 Error: $108.73 SLE: 12.60 Item: Frigidaire Pump Asse...
# 140: Guess: $3.66 Truth: $73.20 Error: $69.54 SLE: 7.66 Item: GE Appliances Washer...
# 141: Guess: $1.82 Truth: $29.00 Error: $27.18 SLE: 5.60 Item: Rattleware Handle-Fr...
# 142: Guess: $4.96 Truth: $34.71 Error: $29.75 SLE: 3.21 Item: Samsung - SAMSUNG RE...
# 143: Guess: $1.92 Truth: $24.46 Error: $22.54 SLE: 4.69 Item: Compatible Dryer Bel...
# 144: Guess: $4.45 Truth: $9.99 Error: $5.54 SLE: 0.49 Item: 303836 Dryer Blower ...
# 145: Guess: $3.02 Truth: $6.95 Error: $3.93 SLE: 0.46 Item: Mini Hygrometer Ther...
# 146: Guess: $7.31 Truth: $7.99 Error: $0.68 SLE: 0.01 Item: Refrigerator Defrost...
# 147: Guess: $3.00 Truth: $34.89 Error: $31.89 SLE: 4.81 Item: Greture Kitchen Cow ...
# 148: Guess: $2.40 Truth: $33.99 Error: $31.59 SLE: 5.43 Item: Dryer Heating Elemen...
# 149: Guess: $3.00 Truth: $4.45 Error: $1.45 SLE: 0.10 Item: GENUINE Whirlpool 98...
# 150: Guess: $2.58 Truth: $9.29 Error: $6.71 SLE: 1.12 Item: American Metal Filte...
# 151: Guess: $3.67 Truth: $69.09 Error: $65.42 SLE: 7.33 Item: LG Genuine OEM Conve...
# 152: Guess: $1.41 Truth: $191.25 Error: $189.84 SLE: 19.18 Item: Nostalgic Warehouse ...
# 153: Guess: $1.92 Truth: $28.12 Error: $26.20 SLE: 5.29 Item: Upgraded Lifetime Ap...
# 154: Guess: $4.02 Truth: $58.49 Error: $54.47 SLE: 6.11 Item: Frigidaire Lower Was...
# 155: Guess: $3.95 Truth: $21.86 Error: $17.91 SLE: 2.34 Item: Whirlpool Range Roun...
# 156: Guess: $4.07 Truth: $108.85 Error: $104.78 SLE: 9.46 Item: Whirlpool Washer Agi...
# 157: Guess: $1.94 Truth: $8.00 Error: $6.06 SLE: 1.25 Item: Southbend Range Sect...
# 158: Guess: $1.64 Truth: $9.97 Error: $8.33 SLE: 2.03 Item: Ultra Durable Refrig...
# 159: Guess: $2.20 Truth: $27.27 Error: $25.07 SLE: 4.75 Item: Beaquicy Oven Bake E...
# 160: Guess: $3.74 Truth: $18.95 Error: $15.21 SLE: 2.06 Item: 58mm Espresso Filter...
# 161: Guess: $1.72 Truth: $24.99 Error: $23.27 SLE: 5.10 Item: TOADDMOS Refrigerato...
# 162: Guess: $2.60 Truth: $9.69 Error: $7.09 SLE: 1.19 Item: washing machine door...
# 163: Guess: $1.63 Truth: $12.29 Error: $10.66 SLE: 2.62 Item: Supplying Demand Ref...
# 164: Guess: $2.81 Truth: $35.99 Error: $33.18 SLE: 5.17 Item: Supplying Demand Clo...
# 165: Guess: $2.08 Truth: $58.58 Error: $56.50 SLE: 8.77 Item: Saeco Tea/Brass Fauc...
# 166: Guess: $1.60 Truth: $13.99 Error: $12.39 SLE: 3.07 Item: 54mm Bottomless Port...
# 167: Guess: $1.93 Truth: $41.90 Error: $39.97 SLE: 7.21 Item: Frigidaire Refrigera...
# 168: Guess: $1.76 Truth: $17.25 Error: $15.49 SLE: 3.57 Item: Dishwasher Upper Dis...
# 169: Guess: $2.60 Truth: $34.99 Error: $32.39 SLE: 5.30 Item: ICEPURE Replacement ...
# 170: Guess: $1.02 Truth: $10.99 Error: $9.97 SLE: 3.18 Item: Replacement for Aman...
# 171: Guess: $3.56 Truth: $10.59 Error: $7.03 SLE: 0.87 Item: HPUY Y-Clip Assembly...
# 172: Guess: $2.78 Truth: $50.94 Error: $48.16 SLE: 6.87 Item: Pitco Stainlesss Ste...
# 173: Guess: $4.94 Truth: $25.99 Error: $21.05 SLE: 2.29 Item: OEM Refrigerator Dis...
# 174: Guess: $1.35 Truth: $114.99 Error: $113.64 SLE: 15.21 Item: Kismile Small Freeze...
# 175: Guess: $3.58 Truth: $4.98 Error: $1.40 SLE: 0.07 Item: Aleene's Clothes-Was...
# 176: Guess: $2.17 Truth: $19.99 Error: $17.82 SLE: 3.57 Item: Refrigerator Door Bi...
# 177: Guess: $4.03 Truth: $69.50 Error: $65.47 SLE: 6.97 Item: Edgewater Parts Repl...
# 178: Guess: $1.44 Truth: $9.02 Error: $7.58 SLE: 1.99 Item: Honeywell H12015 Rep...
# 179: Guess: $2.94 Truth: $63.00 Error: $60.06 SLE: 7.77 Item: Appliance Art Instan...
# 180: Guess: $2.95 Truth: $11.77 Error: $8.82 SLE: 1.38 Item: Dishwasher Diverter ...
# 181: Guess: $1.78 Truth: $27.14 Error: $25.36 SLE: 5.35 Item: Supco WV8046 Replace...
# 182: Guess: $2.93 Truth: $71.43 Error: $68.50 SLE: 8.49 Item: Whirlpool Lid Switch...
# 183: Guess: $1.73 Truth: $253.31 Error: $251.58 SLE: 20.55 Item: LG Main Control Boar...
# 184: Guess: $2.43 Truth: $15.80 Error: $13.37 SLE: 2.52 Item: 8 Pack Air Filter Re...
# 185: Guess: $1.33 Truth: $10.99 Error: $9.66 SLE: 2.68 Item: 6 Pack Replacement P...
# 186: Guess: $2.09 Truth: $146.99 Error: $144.90 SLE: 14.96 Item: SPT Portable Ice Mak...
# 187: Guess: $5.95 Truth: $569.99 Error: $564.04 SLE: 19.43 Item: Single Wall Oven, GA...
# 188: Guess: $2.11 Truth: $20.89 Error: $18.78 SLE: 3.81 Item: Dishwasher Diverter ...
# 189: Guess: $2.15 Truth: $8.38 Error: $6.23 SLE: 1.19 Item: White Disc Coffee Fi...
# 190: Guess: $1.55 Truth: $26.99 Error: $25.44 SLE: 5.75 Item: Upgraded Stove Knob ...
# 191: Guess: $2.02 Truth: $34.45 Error: $32.43 SLE: 6.06 Item: General Electric Dry...
# 192: Guess: $1.67 Truth: $14.99 Error: $13.32 SLE: 3.20 Item: 2-Pack Dryer Lint Fi...
# 193: Guess: $1.57 Truth: $17.94 Error: $16.37 SLE: 3.99 Item: Samsung Refrigerator...
# 194: Guess: $4.16 Truth: $265.00 Error: $260.84 SLE: 15.54 Item: FreezerMax System. O...
# 195: Guess: $3.54 Truth: $28.43 Error: $24.89 SLE: 3.49 Item: Washers & Dryers Was...
# 196: Guess: $1.43 Truth: $18.70 Error: $17.27 SLE: 4.39 Item: Compatible Lint Scre...
# 197: Guess: $1.64 Truth: $19.95 Error: $18.31 SLE: 4.29 Item: GE Dishwasher Rack R...
# 198: Guess: $3.43 Truth: $64.70 Error: $61.27 SLE: 7.28 Item: Frigidaire Water Act...
# 199: Guess: $1.79 Truth: $397.05 Error: $395.26 SLE: 24.60 Item: Prince Castle 511 To...
# 200: Guess: $1.38 Truth: $27.79 Error: $26.41 SLE: 6.21 Item: WISINY Compatible fo...
# 201: Guess: $5.53 Truth: $67.99 Error: $62.46 SLE: 5.56 Item: Supplying Demand Ref...
# 202: Guess: $2.20 Truth: $31.47 Error: $29.27 SLE: 5.37 Item: Beaquicy Oven Bake E...
# 203: Guess: $1.40 Truth: $17.64 Error: $16.24 SLE: 4.21 Item: Fluidmaster 12IM72 B...
# 204: Guess: $1.56 Truth: $12.79 Error: $11.23 SLE: 2.84 Item: American Metal Filte...
# 205: Guess: $1.65 Truth: $23.44 Error: $21.79 SLE: 4.93 Item: for Electrolux Frigi...
# 206: Guess: $1.42 Truth: $5.99 Error: $4.57 SLE: 1.12 Item: Replacement HDC-12 f...
# 207: Guess: $1.48 Truth: $159.99 Error: $158.51 SLE: 17.41 Item: KRIB BLING Compact R...
# 208: Guess: $1.51 Truth: $29.99 Error: $28.48 SLE: 6.32 Item: WISINY Washer Lid Lo...
# 209: Guess: $1.34 Truth: $16.66 Error: $15.32 SLE: 4.09 Item: Upgraded Pump Gasket...
# 210: Guess: $1.56 Truth: $22.99 Error: $21.43 SLE: 5.00 Item: FETIONS (Left) & (Ri...
# 211: Guess: $2.63 Truth: $35.99 Error: $33.36 SLE: 5.39 Item: Supplying Demand Ref...
# 212: Guess: $2.02 Truth: $16.88 Error: $14.86 SLE: 3.16 Item: Gashwer Upgraded Upp...
# 213: Guess: $2.73 Truth: $25.99 Error: $23.26 SLE: 3.92 Item: Multi-Functional Mov...
# 214: Guess: $2.82 Truth: $39.96 Error: $37.14 SLE: 5.62 Item: Compatible Range Gas...
# 215: Guess: $3.00 Truth: $39.99 Error: $36.99 SLE: 5.42 Item: Wine Kitchen Dishwas...
# 216: Guess: $1.84 Truth: $16.00 Error: $14.16 SLE: 3.20 Item: AYZE Electric Restri...
# 217: Guess: $1.63 Truth: $12.99 Error: $11.36 SLE: 2.80 Item: Gxcdizx 1 Pc Refrige...
# 218: Guess: $1.85 Truth: $38.00 Error: $36.15 SLE: 6.84 Item: PRODUCTZ 100% Metal ...
# 219: Guess: $3.85 Truth: $484.17 Error: $480.32 SLE: 21.21 Item: Empava Island Range ...
# 220: Guess: $1.56 Truth: $15.99 Error: $14.43 SLE: 3.58 Item: 2PCS Washing Machine...
# 221: Guess: $1.78 Truth: $21.99 Error: $20.21 SLE: 4.46 Item: CTUER Washer Dryer M...
# 222: Guess: $1.95 Truth: $29.99 Error: $28.04 SLE: 5.53 Item: Washer Switch for Wh...
# 223: Guess: $1.42 Truth: $13.10 Error: $11.68 SLE: 3.11 Item: Whirlpool Snubber, 1...
# 224: Guess: $2.93 Truth: $799.99 Error: $797.06 SLE: 28.28 Item: COLZER 24 inch Bever...
# 225: Guess: $1.54 Truth: $12.99 Error: $11.45 SLE: 2.90 Item: Protac New Dryer Rel...
# 226: Guess: $2.71 Truth: $37.99 Error: $35.28 SLE: 5.53 Item: Supplying Demand Ref...
# 227: Guess: $1.89 Truth: $17.50 Error: $15.61 SLE: 3.45 Item: Dianoo Milk Pitcher,...
# 228: Guess: $2.22 Truth: $28.99 Error: $26.77 SLE: 4.98 Item: 3-Pack Replacement f...
# 229: Guess: $1.95 Truth: $16.93 Error: $14.98 SLE: 3.25 Item: Whirlpool Control Kn...
# 230: Guess: $1.30 Truth: $14.19 Error: $12.89 SLE: 3.56 Item: Brand New Refrigerat...
# 231: Guess: $2.01 Truth: $24.99 Error: $22.98 SLE: 4.64 Item: Replacement for Kenm...
# 232: Guess: $3.67 Truth: $139.99 Error: $136.32 SLE: 11.61 Item: ForeverPRO Ice Maker...
# 233: Guess: $3.30 Truth: $5.50 Error: $2.20 SLE: 0.17 Item: Fill 'n Brew Reusabl...
# 234: Guess: $2.17 Truth: $11.76 Error: $9.59 SLE: 1.94 Item: Whirlpool FILTER,Cha...
# 235: Guess: $2.02 Truth: $21.99 Error: $19.97 SLE: 4.12 Item: Dishwasher Heating E...
# 236: Guess: $2.44 Truth: $29.97 Error: $27.53 SLE: 4.83 Item: 279838 Dryer Heating...
# 237: Guess: $4.96 Truth: $72.86 Error: $67.90 SLE: 6.33 Item: Aprilaire 4040 Solen...
# 238: Guess: $2.89 Truth: $41.20 Error: $38.31 SLE: 5.69 Item: ForeverPRO 786324 Ov...
# 239: Guess: $1.66 Truth: $6.91 Error: $5.25 SLE: 1.19 Item: HQRP 4-Pack Foam Fil...
# 240: Guess: $1.58 Truth: $33.88 Error: $32.30 SLE: 6.78 Item: Stove Gap Covers Sta...
# 241: Guess: $2.99 Truth: $40.97 Error: $37.98 SLE: 5.53 Item: ForeverPRO Console C...
# 242: Guess: $1.49 Truth: $19.67 Error: $18.18 SLE: 4.49 Item: Lifetime Washer Wate...
# 243: Guess: $1.37 Truth: $18.49 Error: $17.12 SLE: 4.44 Item: Black Porcelain Burn...
# 244: Guess: $1.57 Truth: $27.59 Error: $26.02 SLE: 5.80 Item: 2pcs Refrigerator Do...
# 245: Guess: $1.54 Truth: $12.99 Error: $11.45 SLE: 2.92 Item: 2-Pack Defrost Timer...
# 246: Guess: $4.06 Truth: $5.91 Error: $1.85 SLE: 0.10 Item: HQRP E12 Candelabra ...
# 247: Guess: $1.42 Truth: $25.99 Error: $24.57 SLE: 5.83 Item: HOMFILBIT 1043 Super...
# 248: Guess: $1.42 Truth: $18.99 Error: $17.57 SLE: 4.47 Item: Pulluty and Chrome S...
# 249: Guess: $1.94 Truth: $25.69 Error: $23.75 SLE: 4.86 Item: Replacement UHS24 So...
# 250: Guess: $3.05 Truth: $24.29 Error: $21.24 SLE: 3.35 Item: Hemoton Range Hood F...
